# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0

# %%
my_tensor = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.float32).to("mps")
print(my_tensor)

new_tensor = torch.tensor(1, dtype=torch.float32)
print(new_tensor)

print(my_tensor + new_tensor.to("mps"))

print(torch.mps.is_available())
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]], device='mps:0')
# tensor(1.)
# tensor([[2., 3., 4.],
#         [5., 6., 7.]], device='mps:0')
# True
